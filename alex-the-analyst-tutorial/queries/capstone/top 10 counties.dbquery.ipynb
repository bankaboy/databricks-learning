-- %%
select
  county_state_name,
  population,
  cast(replace(`GHG emissions mtons CO2e`, ',', '') as double) as total_emisions
from 
  emissions.default.emissions_data
order by 
  total_emisions desc
limit 10
