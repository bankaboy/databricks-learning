# %% [markdown]
# using the genie assistant with the instructions as "can you give us the sample nyc taxi data?"

# %%
df = spark.sql("select * from samples.nyctaxi.trips")
display(df)

# %% [markdown]
# query - Can you convert this to SQL

# %%
# %sql
SELECT * FROM samples.nyctaxi.trips
